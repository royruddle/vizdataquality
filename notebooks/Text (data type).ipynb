# %% [markdown]
# # Textual data

# %% [markdown]
# This example shows how textual data can be visualized within a plot.

# %% [markdown]
# ## Includes: viz_data_quality and other libraries

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib as mpl
import matplotlib.pyplot as plt

from vizdataquality import calculate as vduc, datasets as vdqd, plot as vdqp

# %% [markdown]
# ## Get a dataframe's profile

# %%
num_rows, df = vdqd.get_dataset('simple')
df_output = vdqd.calc(df)
print('Number of rows =', num_rows)
column = 'Data type'
print()
print(column)
print(df_output[column])
# Out:
# Number of rows = 10
#
# Data type
# _column
# String             object
# Integer             int64
# Float             float64
# Date       datetime64[ns]
# Name: Data type, dtype: object

# %% [markdown]
# ## Visualize text

# %%
vdqp.text(df_output[column])

# %% [markdown]
# ## Customise the visualization

# %%
# A dictionary of keyword arguments that are passed to the Matplotlib Figure object
fig_kw = {'size_inches': (1.5, 1.1), 'dpi': 300}
vdqp.text(df_output[column], filename='missing values.jpg', overwrite=False, fig_kw=fig_kw)
# Out:
# ** WARNING ** vizdataquality, plot.py, _draw_fig(): Figure not output because a file with the supplied name already exists.
# missing values.jpg
